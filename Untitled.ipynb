# %%
import pandas as pd

# %%
df = pd.read_excel("datatst.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Order ID     3 non-null      int64
#  1   Date         3 non-null      datetime64[ns]
#  2   Product      3 non-null      object
#  3   Quantity     3 non-null      int64
#  4   Price        3 non-null      int64
#  5   Customer ID  3 non-null      int64
#  6   City         3 non-null      object
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 300.0+ bytes

# %%
df.head()
# Out:
#    Order ID       Date     Product  Quantity  Price  Customer ID         City
# 0       101 2024-01-01      Laptop         1   1000          201     New York
# 1       102 2024-01-02       Phone         2    500          202  Los Angeles
# 2       103 2024-01-03  Headphones         3     50          203      Chicago

# %%
df.describe()
# Out:
#        Order ID                 Date  Quantity        Price  Customer ID
# count       3.0                    3       3.0     3.000000          3.0
# mean      102.0  2024-01-02 00:00:00       2.0   516.666667        202.0
# min       101.0  2024-01-01 00:00:00       1.0    50.000000        201.0
# 25%       101.5  2024-01-01 12:00:00       1.5   275.000000        201.5
# 50%       102.0  2024-01-02 00:00:00       2.0   500.000000        202.0
# 75%       102.5  2024-01-02 12:00:00       2.5   750.000000        202.5
# max       103.0  2024-01-03 00:00:00       3.0  1000.000000        203.0
# std         1.0                  NaN       1.0   475.219248          1.0

# %%
df.shape
# Out:
# (3, 7)

# %%
df.isnull().sum()
# Out:
# Order ID       0
# Date           0
# Product        0
# Quantity       0
# Price          0
# Customer ID    0
# City           0
# dtype: int64

# %%
df.sort_values("Customer ID", ascending=True)
# Out:
#    Order ID       Date     Product  Quantity  Price  Customer ID         City
# 0       101 2024-01-01      Laptop         1   1000          201     New York
# 1       102 2024-01-02       Phone         2    500          202  Los Angeles
# 2       103 2024-01-03  Headphones         3     50          203      Chicago

# %%
df["Price"].sum()
# Out:
# 1550

# %%
df.groupby("Product")["Price"].sum()
# Out:
# Product
# Headphones      50
# Laptop        1000
# Phone          500
# Name: Price, dtype: int64

# %%
df.groupby("City")["Price"].sum()
# Out:
# City
# Chicago          50
# Los Angeles     500
# New York       1000
# Name: Price, dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Day of Week'] = df['Date'].dt.day_name()

# %%
df.head()
# Out:
#    Order ID       Date     Product  Quantity  Price  Customer ID         City  \
# 0       101 2024-01-01      Laptop         1   1000          201     New York
# 1       102 2024-01-02       Phone         2    500          202  Los Angeles
# 2       103 2024-01-03  Headphones         3     50          203      Chicago
#
#   Day of Week
# 0      Monday
# 1     Tuesday
# 2   Wednesday

# %%
sales_by_day = df.groupby('Day of Week')['Price'].sum()

# %%
sales_by_day
# Out:
# Day of Week
# Monday       1000
# Tuesday       500
# Wednesday      50
# Name: Price, dtype: int64
